# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Finance_Club_Project/Dataset/train_dataset_final1.csv")

# %%
df.sample(10)
# Out:
#        Customer_ID  marriage  sex  education  LIMIT_BAL   age  pay_0  pay_2  \
# 8896         13913         2    0          2      50000  31.0     -1     -1
# 23745        28762         1    1          2     480000  46.0     -1     -1
# 377           5394         2    1          1     320000  29.0      0      0
# 9056         14073         1    0          1     180000  40.0     -2     -2
# 23562        28579         1    1          1     200000  35.0     -1     -1
# 17173        22190         2    0          2      20000  21.0      0      0
# 18142        23159         2    1          1      80000  36.0      2      0
# 21162        26179         1    1          3     150000  45.0      0      0
# 18517        23534         1    1          3     400000  44.0      0      0
# 18124        23141         2    1          2      60000  26.0      0      0
#
#        pay_3  pay_4  ...  Bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25247 entries, 0 to 25246
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         25247 non-null  int64
#  1   marriage            25247 non-null  int64
#  2   sex                 25247 non-null  int64
#  3   education           25247 non-null  int64
#  4   LIMIT_BAL           25247 non-null  int64
#  5   age                 25121 non-null  float64
#  6   pay_0               25247 non-null  int64
#  7   pay_2               25247 non-null  int64
#  8   pay_3               25247 non-null  int64
#  9   pay_4               25247 non-null  int64
#  10  pay_5               25247 non-null  int64
#  11  pay_6               25247 non-null  int64
#  12  Bill_amt1           25247 non-null  float64
#  13  Bill_amt2           25247 non-null  float64
#  14  Bill_amt3           25247 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# marriage                0
# sex                     0
# education               0
# LIMIT_BAL               0
# age                   126
# pay_0                   0
# pay_2                   0
# pay_3                   0
# pay_4                   0
# pay_5                   0
# pay_6                   0
# Bill_amt1               0
# Bill_amt2               0
# Bill_amt3               0
# Bill_amt4               0
# Bill_amt5               0
# Bill_amt6               0
# pay_amt1                0
# pay_amt2                0
# pay_amt3                0
# pay_amt4                0
# pay_amt5                0
# pay_amt6                0
# AVG_Bill_amt            0
# PAY_TO_BILL_ratio       0
# next_month_default      0
# dtype: int64

# %%
df.describe()
# Out:
#         Customer_ID      marriage           sex     education       LIMIT_BAL  \
# count  25247.000000  25247.000000  25247.000000  25247.000000    25247.000000
# mean   17640.000000      1.551907      0.604111      1.852101   168342.060443
# std     7288.325459      0.522629      0.489050      0.797379   129892.784807
# min     5017.000000      0.000000      0.000000      0.000000    10000.000000
# 25%    11328.500000      1.000000      0.000000      1.000000    50000.000000
# 50%    17640.000000      2.000000      1.000000      2.000000   140000.000000
# 75%    23951.500000      2.000000      1.000000      2.000000   240000.000000
# max    30263.000000      3.000000      1.000000      6.000000  1000000.000000
#
#                 age         pay_0         pay_2         pay_3         pay_4  \
# count  25121.000000  25247.000000  25247.000000  25247.000000  25247.000000
# mean      35.438199     -0.042857     -0.159544     -0.190359     -0.241415
# ...

# %%
df['age'].fillna(df['age'].mean(), inplace = True)
# Out:
# /tmp/ipykernel_1366/121903411.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Customer_ID           0
# marriage              0
# sex                   0
# education             0
# LIMIT_BAL             0
# age                   0
# pay_0                 0
# pay_2                 0
# pay_3                 0
# pay_4                 0
# pay_5                 0
# pay_6                 0
# Bill_amt1             0
# Bill_amt2             0
# Bill_amt3             0
# Bill_amt4             0
# Bill_amt5             0
# Bill_amt6             0
# pay_amt1              0
# pay_amt2              0
# pay_amt3              0
# pay_amt4              0
# pay_amt5              0
# pay_amt6              0
# AVG_Bill_amt          0
# PAY_TO_BILL_ratio     0
# next_month_default    0
# dtype: int64

# %%
df['next_month_default'].value_counts()
# Out:
# next_month_default
# 0    20440
# 1     4807
# Name: count, dtype: int64

# %% [markdown]
# # Categorical Data

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    15252
# 0     9995
# Name: count, dtype: int64

# %%
df['marriage'].value_counts()
# Out:
# marriage
# 2    13441
# 1    11480
# 3      273
# 0       53
# Name: count, dtype: int64

# %%
sns.countplot(x='marriage', data=df)
plt.title('Countplot of Marriage')
plt.show()

# %%
df['marriage'] = df['marriage'].replace(0,3)

# %%
df['marriage'].value_counts()
# Out:
# marriage
# 2    13441
# 1    11480
# 3      326
# Name: count, dtype: int64

# %%
df['education'].value_counts()
# Out:
# education
# 2    11717
# 1     8988
# 3     4115
# 5      253
# 4      116
# 6       44
# 0       14
# Name: count, dtype: int64

# %%
sns.countplot(x='education', data=df)
plt.title('Countplot of Education')
plt.show()

# %%
df['education'] = df['education'].replace([0,5,6],4)

# %%
df['education'].value_counts()
# Out:
# education
# 2    11717
# 1     8988
# 3     4115
# 4      427
# Name: count, dtype: int64

# %%
# sex vs next_month_default

pd.crosstab(df['sex'], df['next_month_default'])
# Out:
# next_month_default      0     1
# sex
# 0                    7910  2085
# 1                   12530  2722

# %%
# marriage vs next_month_default

pd.crosstab(df['marriage'], df['next_month_default'])
# Out:
# next_month_default      0     1
# marriage
# 1                    9141  2339
# 2                   11037  2404
# 3                     262    64

# %%
# education vs next_month_default

pd.crosstab(df['education'], df['next_month_default'])
# Out:
# next_month_default     0     1
# education
# 1                   7534  1454
# 2                   9267  2450
# 3                   3238   877
# 4                    401    26

# %% [markdown]
# # Numerical Data

# %%
sns.distplot(df['age'])
# Out:
# /tmp/ipykernel_1366/3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
sns.barplot(x=df['next_month_default'], y=df['age'])
# Out:
# <Axes: xlabel='next_month_default', ylabel='age'>

# %%
df['age'].describe()
# Out:
# count    25247.000000
# mean        35.438199
# std          9.152073
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: age, dtype: float64

# %%
df['age'].skew()
# Out:
# np.float64(0.7403471615778852)

# %%
sns.distplot(df[df['next_month_default']==0]['age'], hist=False)
sns.distplot(df[df['next_month_default']==1]['age'], hist=False)
# Out:
# /tmp/ipykernel_1366/3889959080.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['next_month_default']==0]['age'], hist=False)
# /tmp/ipykernel_1366/3889959080.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.boxplot(x=df['LIMIT_BAL'])
# Out:
# <Axes: xlabel='LIMIT_BAL'>

# %%
sns.histplot(df[df['next_month_default']==0]['LIMIT_BAL'])
# Out:
# <Axes: xlabel='LIMIT_BAL', ylabel='Count'>

# %%
sns.barplot(x=df['next_month_default'], y=df['LIMIT_BAL'])
# Out:
# <Axes: xlabel='next_month_default', ylabel='LIMIT_BAL'>
